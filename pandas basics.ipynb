# %%
import pandas

# %%
df = pandas.read_csv('Demo Datasets/Lesson 3/middle_tn_schools.csv')

# %%
df
# Out:
#                              name  school_rating   size  reduced_lunch  \
# 0     Allendale Elementary School            5.0  851.0           10.0
# 1             Anderson Elementary            2.0  412.0           71.0
# 2                Avoca Elementary            4.0  482.0           43.0
# 3                   Bailey Middle            0.0  394.0           91.0
# 4             Barfield Elementary            4.0  948.0           26.0
# ..                            ...            ...    ...            ...
# 342  Winfree Bryant Middle School            3.0  611.0           57.0
# 343    Winstead Elementary School            5.0  515.0            8.0
# 344           Woodland Elementary            4.0  424.0           55.0
# 345        Woodland Middle School            5.0  866.0            2.0
# 346                 Wright Middle            0.0  829.0           89.0
#
#      state_percentile_16  state_percentile_15  stu_teach_ratio    school_type  \
# 0                   90.2                 95.8             15.7         Public
# 1                   32.8                 37.3             12.8         Public
# 2                   78.4                 83.6             16.6         Public
# 3                    1.6                  1.0             13.1  Public Magnet
# 4                   85.3                 89.2             14.8         Public
# ..                   ...                  ...              ...            ...
# 342                 59.1                 65.2             16.9         Public
# 343                 93.9                 97.0             14.3         Public
# 344                 84.8                 76.7             14.1         Public
# 345                 93.3                 97.1             19.2         Public
# 346                  4.5                  1.2             16.5         Public
#
#      avg_score_15  avg_score_16  full_time_teachers  percent_black  \
# 0            89.4          85.2                54.0            2.9
# 1            43.0          38.3                32.0            3.9
# 2            75.7          73.0                29.0            1.0
# 3             2.1           4.4                30.0           80.7
# 4            81.3          79.6                64.0           11.8
# ..            ...           ...                 ...            ...
# 342          61.4          57.7                36.0           15.2
# 343          92.0          89.3                36.0            3.3
# 344          69.4          79.4                30.0           11.6
# 345          89.8          84.9                45.0            4.5
# 346           2.7           9.6                50.0           22.3
#
#      percent_white  percent_asian  percent_hispanic
# 0             85.5            1.6               5.6
# 1             86.7            1.0               4.9
# 2             91.5            1.2               4.4
# 3             11.7            2.3               4.3
# 4             71.2            7.1               6.0
# ..             ...            ...               ...
# 342           66.3            1.5              15.7
# 343           87.4            3.1               4.1
# 344           70.5            2.1               9.7
# 345           77.6           10.0               4.4
# 346           21.0            6.6              49.5
#
# [347 rows x 15 columns]

# %%
import pandas as pd

# %%
df = pd.read_csv('Demo Datasets/Lesson 3/middle_tn_schools.csv')

# %%
df
# Out:
#                              name  school_rating   size  reduced_lunch  \
# 0     Allendale Elementary School            5.0  851.0           10.0
# 1             Anderson Elementary            2.0  412.0           71.0
# 2                Avoca Elementary            4.0  482.0           43.0
# 3                   Bailey Middle            0.0  394.0           91.0
# 4             Barfield Elementary            4.0  948.0           26.0
# ..                            ...            ...    ...            ...
# 342  Winfree Bryant Middle School            3.0  611.0           57.0
# 343    Winstead Elementary School            5.0  515.0            8.0
# 344           Woodland Elementary            4.0  424.0           55.0
# 345        Woodland Middle School            5.0  866.0            2.0
# 346                 Wright Middle            0.0  829.0           89.0
#
#      state_percentile_16  state_percentile_15  stu_teach_ratio    school_type  \
# 0                   90.2                 95.8             15.7         Public
# 1                   32.8                 37.3             12.8         Public
# 2                   78.4                 83.6             16.6         Public
# 3                    1.6                  1.0             13.1  Public Magnet
# 4                   85.3                 89.2             14.8         Public
# ..                   ...                  ...              ...            ...
# 342                 59.1                 65.2             16.9         Public
# 343                 93.9                 97.0             14.3         Public
# 344                 84.8                 76.7             14.1         Public
# 345                 93.3                 97.1             19.2         Public
# 346                  4.5                  1.2             16.5         Public
#
#      avg_score_15  avg_score_16  full_time_teachers  percent_black  \
# 0            89.4          85.2                54.0            2.9
# 1            43.0          38.3                32.0            3.9
# 2            75.7          73.0                29.0            1.0
# 3             2.1           4.4                30.0           80.7
# 4            81.3          79.6                64.0           11.8
# ..            ...           ...                 ...            ...
# 342          61.4          57.7                36.0           15.2
# 343          92.0          89.3                36.0            3.3
# 344          69.4          79.4                30.0           11.6
# 345          89.8          84.9                45.0            4.5
# 346           2.7           9.6                50.0           22.3
#
#      percent_white  percent_asian  percent_hispanic
# 0             85.5            1.6               5.6
# 1             86.7            1.0               4.9
# 2             91.5            1.2               4.4
# 3             11.7            2.3               4.3
# 4             71.2            7.1               6.0
# ..             ...            ...               ...
# 342           66.3            1.5              15.7
# 343           87.4            3.1               4.1
# 344           70.5            2.1               9.7
# 345           77.6           10.0               4.4
# 346           21.0            6.6              49.5
#
# [347 rows x 15 columns]

# %%
# to check all attributes of a object
dir(pd)
# Out:
# ['BooleanDtype',
#  'Categorical',
#  'CategoricalDtype',
#  'CategoricalIndex',
#  'DataFrame',
#  'DateOffset',
#  'DatetimeIndex',
#  'DatetimeTZDtype',
#  'ExcelFile',
#  'ExcelWriter',
#  'Float64Index',
#  'Grouper',
#  'HDFStore',
#  'Index',
#  'IndexSlice',
#  'Int16Dtype',
#  'Int32Dtype',
#  'Int64Dtype',
#  'Int64Index',
#  'Int8Dtype',
#  'Interval',
#  'IntervalDtype',
#  'IntervalIndex',
#  'MultiIndex',
#  'NA',
#  'NaT',
#  'NamedAgg',
#  'Period',
#  'PeriodDtype',
#  'PeriodIndex',
#  'RangeIndex',
#  'Series',
#  'SparseDtype',
#  'StringDtype',
#  'Timedelta',
#  'TimedeltaIndex',
#  'Timestamp',
#  'UInt16Dtype',
#  'UInt32Dtype',
#  'UInt64Dtype',
#  'UInt64Index',
#  'UInt8Dtype',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__docformat__',
#  '__file__',
#  '__getattr__',
#  '__git_version__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_config',
#  '_hashtable',
#  '_is_numpy_dev',
#  '_lib',
#  '_libs',
#  '_np_version_under1p16',
#  '_np_version_under1p17',
#  '_np_version_under1p18',
#  '_testing',
#  '_tslib',
#  '_typing',
#  '_version',
#  'api',
#  'array',
#  'arrays',
#  'bdate_range',
#  'compat',
#  'concat',
#  'core',
#  'crosstab',
#  'cut',
#  'date_range',
#  'describe_option',
#  'errors',
#  'eval',
#  'factorize',
#  'get_dummies',
#  'get_option',
#  'infer_freq',
#  'interval_range',
#  'io',
#  'isna',
#  'isnull',
#  'json_normalize',
#  'lreshape',
#  'melt',
#  'merge',
#  'merge_asof',
#  'merge_ordered',
#  'notna',
#  'notnull',
#  'offsets',
#  'option_context',
#  'options',
#  'pandas',
#  'period_range',
#  'pivot',
#  'pivot_table',
#  'plotting',
#  'qcut',
#  'read_clipboard',
#  'read_csv',
#  'read_excel',
#  'read_feather',
#  'read_fwf',
#  'read_gbq',
#  'read_hdf',
#  'read_html',
#  'read_json',
#  'read_orc',
#  'read_parquet',
#  'read_pickle',
#  'read_sas',
#  'read_spss',
#  'read_sql',
#  'read_sql_query',
#  'read_sql_table',
#  'read_stata',
#  'read_table',
#  'reset_option',
#  'set_eng_float_format',
#  'set_option',
#  'show_versions',
#  'test',
#  'testing',
#  'timedelta_range',
#  'to_datetime',
#  'to_numeric',
#  'to_pickle',
#  'to_timedelta',
#  'tseries',
#  'unique',
#  'util',
#  'value_counts',
#  'wide_to_long']

# %%
# Problem Statement 1 : Lesson 2

# %%
data = pd.read_csv('Demo Datasets/Lesson 3/SalaryGender.csv')

# %%
data
# Out:
#     Salary  Gender  Age  PhD
# 0    140.0       1   47    1
# 1     30.0       0   65    1
# 2     35.1       0   56    0
# 3     30.0       1   23    0
# 4     80.0       0   53    1
# ..     ...     ...  ...  ...
# 95    18.6       1   26    0
# 96   152.0       1   56    1
# 97     1.8       1   28    0
# 98    35.0       0   44    0
# 99     4.0       0   24    0
#
# [100 rows x 4 columns]

# %%
import numpy as np

# %%
salary_arr = np.array(data['Salary'])

# %%
salary_arr
# Out:
# array([140.  ,  30.  ,  35.1 ,  30.  ,  80.  ,  30.  ,  60.  ,  31.1 ,
#        125.  ,  51.  ,   3.  ,  46.  , 150.  ,   3.  , 130.  ,  15.  ,
#        130.  ,  84.  , 190.  ,  74.  ,  73.  ,  10.  ,  50.  ,   7.  ,
#          9.5 ,  15.2 ,  28.6 ,  20.  ,  72.  ,  81.  , 100.  ,  90.  ,
#         90.  ,  35.  ,  30.  ,  25.  ,  52.  ,   9.  ,  63.  ,  72.  ,
#         16.  ,  92.  , 106.  ,   2.5 ,   9.  ,  32.  ,  32.  ,  55.  ,
#         52.  ,  28.  ,  20.  ,  14.7 ,  22.3 ,  34.8 ,  84.  ,  19.  ,
#        160.  ,  65.  ,  55.  ,   4.6 , 102.  ,  20.  ,  62.  ,  55.  ,
#         45.6 ,  40.  ,  24.  ,  35.  ,  48.  ,  20.  ,  40.7 ,  15.  ,
#          0.25, 152.  ,  39.8 ,  12.  ,  30.  , 120.  ,   1.7 ,  36.  ,
#         96.  ,  38.  ,  90.  ,   9.  ,  25.8 ,  22.  ,  38.8 ,  72.  ,
#         89.  ,  41.  ,  89.  ,  25.  ,  52.  , 115.  ,  66.  ,  18.6 ,
#        152.  ,   1.8 ,  35.  ,   4.  ])

# %%
# How to access multiple columns
arr = np.array(data[['Salary', 'PhD']])

# %%
arr
# Out:
# array([[140.  ,   1.  ],
#        [ 30.  ,   1.  ],
#        [ 35.1 ,   0.  ],
#        [ 30.  ,   0.  ],
#        [ 80.  ,   1.  ],
#        [ 30.  ,   0.  ],
#        [ 60.  ,   0.  ],
#        [ 31.1 ,   0.  ],
#        [125.  ,   1.  ],
#        [ 51.  ,   1.  ],
#        [  3.  ,   0.  ],
#        [ 46.  ,   0.  ],
#        [150.  ,   1.  ],
#        [  3.  ,   0.  ],
#        [130.  ,   0.  ],
#        [ 15.  ,   0.  ],
#        [130.  ,   0.  ],
#        [ 84.  ,   1.  ],
#        [190.  ,   1.  ],
#        [ 74.  ,   1.  ],
#        [ 73.  ,   0.  ],
#        [ 10.  ,   0.  ],
#        [ 50.  ,   0.  ],
#        [  7.  ,   0.  ],
#        [  9.5 ,   0.  ],
#        [ 15.2 ,   1.  ],
#        [ 28.6 ,   1.  ],
#        [ 20.  ,   0.  ],
#        [ 72.  ,   1.  ],
#        [ 81.  ,   1.  ],
#        [100.  ,   1.  ],
#        [ 90.  ,   1.  ],
#        [ 90.  ,   1.  ],
#        [ 35.  ,   0.  ],
#        [ 30.  ,   0.  ],
#        [ 25.  ,   0.  ],
#        [ 52.  ,   0.  ],
#        [  9.  ,   0.  ],
#        [ 63.  ,   1.  ],
#        [ 72.  ,   0.  ],
#        [ 16.  ,   0.  ],
#        [ 92.  ,   1.  ],
#        [106.  ,   1.  ],
#        [  2.5 ,   0.  ],
#        [  9.  ,   0.  ],
#        [ 32.  ,   1.  ],
#        [ 32.  ,   0.  ],
#        [ 55.  ,   1.  ],
#        [ 52.  ,   0.  ],
#        [ 28.  ,   1.  ],
#        [ 20.  ,   0.  ],
#        [ 14.7 ,   0.  ],
#        [ 22.3 ,   0.  ],
#        [ 34.8 ,   0.  ],
#        [ 84.  ,   1.  ],
#        [ 19.  ,   0.  ],
#        [160.  ,   1.  ],
#        [ 65.  ,   1.  ],
#        [ 55.  ,   0.  ],
#        [  4.6 ,   0.  ],
#        [102.  ,   1.  ],
#        [ 20.  ,   0.  ],
#        [ 62.  ,   0.  ],
#        [ 55.  ,   1.  ],
#        [ 45.6 ,   0.  ],
#        [ 40.  ,   0.  ],
#        [ 24.  ,   0.  ],
#        [ 35.  ,   0.  ],
#        [ 48.  ,   0.  ],
#        [ 20.  ,   0.  ],
#        [ 40.7 ,   0.  ],
#        [ 15.  ,   0.  ],
#        [  0.25,   0.  ],
#        [152.  ,   1.  ],
#        [ 39.8 ,   0.  ],
#        [ 12.  ,   0.  ],
#        [ 30.  ,   1.  ],
#        [120.  ,   1.  ],
#        [  1.7 ,   0.  ],
#        [ 36.  ,   1.  ],
#        [ 96.  ,   1.  ],
#        [ 38.  ,   1.  ],
#        [ 90.  ,   0.  ],
#        [  9.  ,   0.  ],
#        [ 25.8 ,   0.  ],
#        [ 22.  ,   0.  ],
#        [ 38.8 ,   0.  ],
#        [ 72.  ,   1.  ],
#        [ 89.  ,   0.  ],
#        [ 41.  ,   1.  ],
#        [ 89.  ,   1.  ],
#        [ 25.  ,   0.  ],
#        [ 52.  ,   1.  ],
#        [115.  ,   0.  ],
#        [ 66.  ,   1.  ],
#        [ 18.6 ,   0.  ],
#        [152.  ,   1.  ],
#        [  1.8 ,   0.  ],
#        [ 35.  ,   0.  ],
#        [  4.  ,   0.  ]])

# %%
# properties of a DataFrame

# %%
data
# Out:
#     Salary  Gender  Age  PhD
# 0    140.0       1   47    1
# 1     30.0       0   65    1
# 2     35.1       0   56    0
# 3     30.0       1   23    0
# 4     80.0       0   53    1
# ..     ...     ...  ...  ...
# 95    18.6       1   26    0
# 96   152.0       1   56    1
# 97     1.8       1   28    0
# 98    35.0       0   44    0
# 99     4.0       0   24    0
#
# [100 rows x 4 columns]

# %%
data.shape
# Out:
# (100, 4)

# %%
data.dtypes
# Out:
# Salary    float64
# Gender      int64
# Age         int64
# PhD         int64
# dtype: object

# %%
data.astype(float)
# Out:
#     Salary  Gender   Age  PhD
# 0    140.0     1.0  47.0  1.0
# 1     30.0     0.0  65.0  1.0
# 2     35.1     0.0  56.0  0.0
# 3     30.0     1.0  23.0  0.0
# 4     80.0     0.0  53.0  1.0
# ..     ...     ...   ...  ...
# 95    18.6     1.0  26.0  0.0
# 96   152.0     1.0  56.0  1.0
# 97     1.8     1.0  28.0  0.0
# 98    35.0     0.0  44.0  0.0
# 99     4.0     0.0  24.0  0.0
#
# [100 rows x 4 columns]

# %%
data['Salary'].dtype
# Out:
# dtype('float64')

# %%
data['Salary'].astype(int)
# Out:
# 0     140
# 1      30
# 2      35
# 3      30
# 4      80
#      ...
# 95     18
# 96    152
# 97      1
# 98     35
# 99      4
# Name: Salary, Length: 100, dtype: int64

# %%
data.keys()
# Out:
# Index(['Salary', 'Gender', 'Age', 'PhD'], dtype='object')

# %%
data.columns
# Out:
# Index(['Salary', 'Gender', 'Age', 'PhD'], dtype='object')

# %%
data.index
# Out:
# RangeIndex(start=0, stop=100, step=1)

# %%
data.values
# Out:
# array([[140.  ,   1.  ,  47.  ,   1.  ],
#        [ 30.  ,   0.  ,  65.  ,   1.  ],
#        [ 35.1 ,   0.  ,  56.  ,   0.  ],
#        [ 30.  ,   1.  ,  23.  ,   0.  ],
#        [ 80.  ,   0.  ,  53.  ,   1.  ],
#        [ 30.  ,   0.  ,  27.  ,   0.  ],
#        [ 60.  ,   1.  ,  53.  ,   0.  ],
#        [ 31.1 ,   0.  ,  30.  ,   0.  ],
#        [125.  ,   1.  ,  44.  ,   1.  ],
#        [ 51.  ,   1.  ,  63.  ,   1.  ],
#        [  3.  ,   1.  ,  22.  ,   0.  ],
#        [ 46.  ,   1.  ,  59.  ,   0.  ],
#        [150.  ,   1.  ,  60.  ,   1.  ],
#        [  3.  ,   1.  ,  28.  ,   0.  ],
#        [130.  ,   1.  ,  65.  ,   0.  ],
#        [ 15.  ,   0.  ,  25.  ,   0.  ],
#        [130.  ,   1.  ,  65.  ,   0.  ],
#        [ 84.  ,   0.  ,  47.  ,   1.  ],
#        [190.  ,   1.  ,  66.  ,   1.  ],
#        [ 74.  ,   1.  ,  45.  ,   1.  ],
#        [ 73.  ,   0.  ,  46.  ,   0.  ],
#        [ 10.  ,   0.  ,  24.  ,   0.  ],
#        [ 50.  ,   0.  ,  60.  ,   0.  ],
#        [  7.  ,   0.  ,  63.  ,   0.  ],
#        [  9.5 ,   0.  ,  27.  ,   0.  ],
#        [ 15.2 ,   1.  ,  66.  ,   1.  ],
#        [ 28.6 ,   1.  ,  36.  ,   1.  ],
#        [ 20.  ,   0.  ,  30.  ,   0.  ],
#        [ 72.  ,   0.  ,  51.  ,   1.  ],
#        [ 81.  ,   1.  ,  65.  ,   1.  ],
#        [100.  ,   0.  ,  45.  ,   1.  ],
#        [ 90.  ,   0.  ,  52.  ,   1.  ],
#        [ 90.  ,   0.  ,  54.  ,   1.  ],
#        [ 35.  ,   1.  ,  30.  ,   0.  ],
#        [ 30.  ,   0.  ,  52.  ,   0.  ],
#        [ 25.  ,   1.  ,  26.  ,   0.  ],
#        [ 52.  ,   0.  ,  49.  ,   0.  ],
#        [  9.  ,   0.  ,  22.  ,   0.  ],
#        [ 63.  ,   1.  ,  34.  ,   1.  ],
#        [ 72.  ,   1.  ,  60.  ,   0.  ],
#        [ 16.  ,   1.  ,  28.  ,   0.  ],
#        [ 92.  ,   0.  ,  58.  ,   1.  ],
#        [106.  ,   1.  ,  77.  ,   1.  ],
#        [  2.5 ,   1.  ,  67.  ,   0.  ],
#        [  9.  ,   0.  ,  27.  ,   0.  ],
#        [ 32.  ,   0.  ,  48.  ,   1.  ],
#        [ 32.  ,   0.  ,  45.  ,   0.  ],
#        [ 55.  ,   1.  ,  49.  ,   1.  ],
#        [ 52.  ,   1.  ,  36.  ,   0.  ],
#        [ 28.  ,   0.  ,  65.  ,   1.  ],
#        [ 20.  ,   0.  ,  32.  ,   0.  ],
#        [ 14.7 ,   0.  ,  49.  ,   0.  ],
#        [ 22.3 ,   1.  ,  67.  ,   0.  ],
#        [ 34.8 ,   0.  ,  22.  ,   0.  ],
#        [ 84.  ,   0.  ,  49.  ,   1.  ],
#        [ 19.  ,   1.  ,  43.  ,   0.  ],
#        [160.  ,   1.  ,  61.  ,   1.  ],
#        [ 65.  ,   0.  ,  43.  ,   1.  ],
#        [ 55.  ,   0.  ,  52.  ,   0.  ],
#        [  4.6 ,   1.  ,  51.  ,   0.  ],
#        [102.  ,   1.  ,  66.  ,   1.  ],
#        [ 20.  ,   1.  ,  29.  ,   0.  ],
#        [ 62.  ,   0.  ,  62.  ,   0.  ],
#        [ 55.  ,   1.  ,  56.  ,   1.  ],
#        [ 45.6 ,   1.  ,  61.  ,   0.  ],
#        [ 40.  ,   0.  ,  56.  ,   0.  ],
#        [ 24.  ,   0.  ,  41.  ,   0.  ],
#        [ 35.  ,   1.  ,  24.  ,   0.  ],
#        [ 48.  ,   0.  ,  60.  ,   0.  ],
#        [ 20.  ,   0.  ,  43.  ,   0.  ],
#        [ 40.7 ,   0.  ,  57.  ,   0.  ],
#        [ 15.  ,   1.  ,  23.  ,   0.  ],
#        [  0.25,   0.  ,  53.  ,   0.  ],
#        [152.  ,   1.  ,  71.  ,   1.  ],
#        [ 39.8 ,   0.  ,  20.  ,   0.  ],
#        [ 12.  ,   0.  ,  27.  ,   0.  ],
#        [ 30.  ,   1.  ,  69.  ,   1.  ],
#        [120.  ,   1.  ,  58.  ,   1.  ],
#        [  1.7 ,   1.  ,  37.  ,   0.  ],
#        [ 36.  ,   1.  ,  32.  ,   1.  ],
#        [ 96.  ,   1.  ,  33.  ,   1.  ],
#        [ 38.  ,   0.  ,  32.  ,   1.  ],
#        [ 90.  ,   1.  ,  60.  ,   0.  ],
#        [  9.  ,   1.  ,  71.  ,   0.  ],
#        [ 25.8 ,   0.  ,  30.  ,   0.  ],
#        [ 22.  ,   0.  ,  62.  ,   0.  ],
#        [ 38.8 ,   0.  ,  54.  ,   0.  ],
#        [ 72.  ,   1.  ,  42.  ,   1.  ],
#        [ 89.  ,   1.  ,  62.  ,   0.  ],
#        [ 41.  ,   0.  ,  51.  ,   1.  ],
#        [ 89.  ,   1.  ,  71.  ,   1.  ],
#        [ 25.  ,   0.  ,  29.  ,   0.  ],
#        [ 52.  ,   1.  ,  55.  ,   1.  ],
#        [115.  ,   0.  ,  54.  ,   0.  ],
#        [ 66.  ,   0.  ,  55.  ,   1.  ],
#        [ 18.6 ,   1.  ,  26.  ,   0.  ],
#        [152.  ,   1.  ,  56.  ,   1.  ],
#        [  1.8 ,   1.  ,  28.  ,   0.  ],
#        [ 35.  ,   0.  ,  44.  ,   0.  ],
#        [  4.  ,   0.  ,  24.  ,   0.  ]])

# %%
data.index = ['emp'+str(i) for i in range(len(data))]

# %%
data
# Out:
#        Salary  Gender  Age  PhD
# emp0    140.0       1   47    1
# emp1     30.0       0   65    1
# emp2     35.1       0   56    0
# emp3     30.0       1   23    0
# emp4     80.0       0   53    1
# ...       ...     ...  ...  ...
# emp95    18.6       1   26    0
# emp96   152.0       1   56    1
# emp97     1.8       1   28    0
# emp98    35.0       0   44    0
# emp99     4.0       0   24    0
#
# [100 rows x 4 columns]

# %%
data.iloc[30:20:-1, 2:5]
# Out:
#        Age  PhD
# emp30   45    1
# emp29   65    1
# emp28   51    1
# emp27   30    0
# emp26   36    1
# emp25   66    1
# emp24   27    0
# emp23   63    0
# emp22   60    0
# emp21   24    0

# %%
data.loc[['emp1', 'emp3'],['Salary', 'PhD']]
# Out:
#       Salary  PhD
# emp1    30.0    1
# emp3    30.0    0

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
type(data['Salary'])
# Out:
# pandas.core.series.Series

# %%
data.loc['emp3', :]
# Out:
# Salary    30.0
# Gender     1.0
# Age       23.0
# PhD        0.0
# Name: emp3, dtype: float64

# %%
type(data.loc['emp3', :])
# Out:
# pandas.core.series.Series

# %%
data['Gender'] = data['Gender'].astype(str)

# %%
data.dtypes
# Out:
# Salary    float64
# Gender     object
# Age         int64
# PhD         int64
# dtype: object

# %%
data.loc['emp3',:]
# Out:
# Salary    30
# Gender     1
# Age       23
# PhD        0
# Name: emp3, dtype: object

# %%
data.loc['emp3',:].dtype
# Out:
# dtype('O')

# %%
df = pandas.read_csv('Demo Datasets/Lesson 3/middle_tn_schools.csv')

# %%
df.head()
# Out:
#                           name  school_rating   size  reduced_lunch  \
# 0  Allendale Elementary School            5.0  851.0           10.0
# 1          Anderson Elementary            2.0  412.0           71.0
# 2             Avoca Elementary            4.0  482.0           43.0
# 3                Bailey Middle            0.0  394.0           91.0
# 4          Barfield Elementary            4.0  948.0           26.0
#
#    state_percentile_16  state_percentile_15  stu_teach_ratio    school_type  \
# 0                 90.2                 95.8             15.7         Public
# 1                 32.8                 37.3             12.8         Public
# 2                 78.4                 83.6             16.6         Public
# 3                  1.6                  1.0             13.1  Public Magnet
# 4                 85.3                 89.2             14.8         Public
#
#    avg_score_15  avg_score_16  full_time_teachers  percent_black  \
# 0          89.4          85.2                54.0            2.9
# 1          43.0          38.3                32.0            3.9
# 2          75.7          73.0                29.0            1.0
# 3           2.1           4.4                30.0           80.7
# 4          81.3          79.6                64.0           11.8
#
#    percent_white  percent_asian  percent_hispanic
# 0           85.5            1.6               5.6
# 1           86.7            1.0               4.9
# 2           91.5            1.2               4.4
# 3           11.7            2.3               4.3
# 4           71.2            7.1               6.0

# %%
df['school_type'].unique()
# Out:
# array(['Public', 'Public Magnet', 'Public Charter', 'Public Virtual'],
#       dtype=object)

# %%
df['school_type'].nunique()
# Out:
# 4

# %%
df['school_type'].value_counts()
# Out:
# Public            292
# Public Magnet      46
# Public Charter      8
# Public Virtual      1
# Name: school_type, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv('Demo Datasets/Lesson 3/middle_tn_schools.csv')
correlations = df.corr()
ax = sns.heatmap(data = correlations, square = True, cmap='bwr')

plt.yticks(rotation=0)
plt.xticks(rotation=90)
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 347 entries, 0 to 346
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   name                 347 non-null    object
#  1   school_rating        347 non-null    float64
#  2   size                 347 non-null    float64
#  3   reduced_lunch        347 non-null    float64
#  4   state_percentile_16  347 non-null    float64
#  5   state_percentile_15  341 non-null    float64
#  6   stu_teach_ratio      347 non-null    float64
#  7   school_type          347 non-null    object
#  8   avg_score_15         341 non-null    float64
#  9   avg_score_16         347 non-null    float64
#  10  full_time_teachers   347 non-null    float64
#  11  percent_black        347 non-null    float64
#  12  percent_white        347 non-null    float64
#  13  percent_asian        347 non-null    float64
#  14  percent_hispanic     347 non-null    float64
# dtypes: float64(13), object(2)
# memory usage: 40.8+ KB

# %%
quant_df = df.drop(['name', 'school_type'], axis=1)

# %%
df.select_dtypes('float64')
# Out:
#      school_rating   size  reduced_lunch  state_percentile_16  \
# 0              5.0  851.0           10.0                 90.2
# 1              2.0  412.0           71.0                 32.8
# 2              4.0  482.0           43.0                 78.4
# 3              0.0  394.0           91.0                  1.6
# 4              4.0  948.0           26.0                 85.3
# ..             ...    ...            ...                  ...
# 342            3.0  611.0           57.0                 59.1
# 343            5.0  515.0            8.0                 93.9
# 344            4.0  424.0           55.0                 84.8
# 345            5.0  866.0            2.0                 93.3
# 346            0.0  829.0           89.0                  4.5
#
#      state_percentile_15  stu_teach_ratio  avg_score_15  avg_score_16  \
# 0                   95.8             15.7          89.4          85.2
# 1                   37.3             12.8          43.0          38.3
# 2                   83.6             16.6          75.7          73.0
# 3                    1.0             13.1           2.1           4.4
# 4                   89.2             14.8          81.3          79.6
# ..                   ...              ...           ...           ...
# 342                 65.2             16.9          61.4          57.7
# 343                 97.0             14.3          92.0          89.3
# 344                 76.7             14.1          69.4          79.4
# 345                 97.1             19.2          89.8          84.9
# 346                  1.2             16.5           2.7           9.6
#
#      full_time_teachers  percent_black  percent_white  percent_asian  \
# 0                  54.0            2.9           85.5            1.6
# 1                  32.0            3.9           86.7            1.0
# 2                  29.0            1.0           91.5            1.2
# 3                  30.0           80.7           11.7            2.3
# 4                  64.0           11.8           71.2            7.1
# ..                  ...            ...            ...            ...
# 342                36.0           15.2           66.3            1.5
# 343                36.0            3.3           87.4            3.1
# 344                30.0           11.6           70.5            2.1
# 345                45.0            4.5           77.6           10.0
# 346                50.0           22.3           21.0            6.6
#
#      percent_hispanic
# 0                 5.6
# 1                 4.9
# 2                 4.4
# 3                 4.3
# 4                 6.0
# ..                ...
# 342              15.7
# 343               4.1
# 344               9.7
# 345               4.4
# 346              49.5
#
# [347 rows x 13 columns]

# %%
quant_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 347 entries, 0 to 346
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   school_rating        347 non-null    float64
#  1   size                 347 non-null    float64
#  2   reduced_lunch        347 non-null    float64
#  3   state_percentile_16  347 non-null    float64
#  4   state_percentile_15  341 non-null    float64
#  5   stu_teach_ratio      347 non-null    float64
#  6   avg_score_15         341 non-null    float64
#  7   avg_score_16         347 non-null    float64
#  8   full_time_teachers   347 non-null    float64
#  9   percent_black        347 non-null    float64
#  10  percent_white        347 non-null    float64
#  11  percent_asian        347 non-null    float64
#  12  percent_hispanic     347 non-null    float64
# dtypes: float64(13)
# memory usage: 35.4 KB

# %%
quant_df.describe()
# Out:
#        school_rating         size  reduced_lunch  state_percentile_16  \
# count     347.000000   347.000000     347.000000           347.000000
# mean        2.968300   699.472622      50.279539            58.801729
# std         1.690377   400.598636      25.480236            32.540747
# min         0.000000    53.000000       2.000000             0.200000
# 25%         2.000000   420.500000      30.000000            30.950000
# 50%         3.000000   595.000000      51.000000            66.400000
# 75%         4.000000   851.000000      71.500000            88.000000
# max         5.000000  2314.000000      98.000000            99.800000
#
#        state_percentile_15  stu_teach_ratio  avg_score_15  avg_score_16  \
# count           341.000000       347.000000    341.000000    347.000000
# mean             58.249267        15.461671     57.004692     57.049856
# std              32.702630         5.725170     26.696450     27.968974
# min               0.600000         4.700000      1.500000      0.100000
# 25%              27.100000        13.700000     37.600000     37.000000
# 50%              65.800000        15.000000     61.800000     60.700000
# 75%              88.600000        16.700000     79.600000     80.250000
# max              99.800000       111.000000     99.000000     98.900000
#
#        full_time_teachers  percent_black  percent_white  percent_asian  \
# count          347.000000     347.000000     347.000000     347.000000
# mean            44.939481      21.197983      61.673487       2.642651
# std             22.053386      23.562538      27.274859       3.109629
# min              2.000000       0.000000       1.100000       0.000000
# 25%             30.000000       3.600000      40.600000       0.750000
# 50%             40.000000      13.500000      68.700000       1.600000
# 75%             54.000000      28.350000      85.950000       3.100000
# max            140.000000      97.400000      99.700000      21.100000
#
#        percent_hispanic
# count        347.000000
# mean          11.164553
# std           12.030608
# min            0.000000
# 25%            3.800000
# 50%            6.400000
# 75%           13.800000
# max           65.200000

# %%
quant_df.describe().unstack()
# Out:
# school_rating     count    347.000000
#                   mean       2.968300
#                   std        1.690377
#                   min        0.000000
#                   25%        2.000000
#                               ...
# percent_hispanic  min        0.000000
#                   25%        3.800000
#                   50%        6.400000
#                   75%       13.800000
#                   max       65.200000
# Length: 104, dtype: float64

# %%
dir(quant_df)
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_NAMES',
#  '_AXIS_NUMBERS',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '_AXIS_TO_AXIS_NUMBER',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__nonzero__',
#  '__or__',
#  '__pos__',
#  '__pow__',
#  '__radd__',
#  '__rand__',
#  '__rdiv__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rfloordiv__',
#  '__rmatmul__',
#  '__rmod__',
#  '__rmul__',
#  '__ror__',
#  '__round__',
#  '__rpow__',
#  '__rsub__',
#  '__rtruediv__',
#  '__rxor__',
#  '__setattr__',
#  '__setitem__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
#  '__weakref__',
#  '__xor__',
#  '_accessors',
#  '_add_numeric_operations',
#  '_add_series_or_dataframe_operations',
#  '_agg_by_level',
#  '_agg_examples_doc',
#  '_agg_summary_and_see_also_doc',
#  '_aggregate',
#  '_aggregate_multiple_funcs',
#  '_align_frame',
#  '_align_series',
#  '_box_col_values',
#  '_builtin_table',
#  '_can_fast_transpose',
#  '_check_inplace_setting',
#  '_check_is_chained_assignment_possible',
#  '_check_label_or_level_ambiguity',
#  '_check_setitem_copy',
#  '_clear_item_cache',
#  '_clip_with_one_bound',
#  '_clip_with_scalar',
#  '_combine_frame',
#  '_consolidate',
#  '_consolidate_inplace',
#  '_construct_axes_dict',
#  '_construct_axes_from_arguments',
#  '_construct_result',
#  '_constructor',
#  '_constructor_expanddim',
#  '_constructor_sliced',
#  '_convert',
#  '_count_level',
#  '_cython_table',
#  '_data',
#  '_deprecations',
#  '_dir_additions',
#  '_dir_deletions',
#  '_drop_axis',
#  '_drop_labels_or_levels',
#  '_ensure_valid_index',
#  '_find_valid_index',
#  '_from_arrays',
#  '_get_agg_axis',
#  '_get_axis',
#  '_get_axis_name',
#  '_get_axis_number',
#  '_get_axis_resolvers',
#  '_get_block_manager_axis',
#  '_get_bool_data',
#  '_get_cacher',
#  '_get_cleaned_column_resolvers',
#  '_get_column_array',
#  '_get_cython_func',
#  '_get_index_resolvers',
#  '_get_item_cache',
#  '_get_label_or_level_values',
#  '_get_numeric_data',
#  '_get_value',
#  '_getitem_bool_array',
#  '_getitem_multilevel',
#  '_gotitem',
#  '_indexed_same',
#  '_info_axis',
#  '_info_axis_name',
#  '_info_axis_number',
#  '_info_repr',
#  '_init_mgr',
#  '_internal_names',
#  '_internal_names_set',
#  '_is_builtin_func',
#  '_is_cached',
#  '_is_copy',
#  '_is_homogeneous_type',
#  '_is_label_or_level_reference',
#  '_is_label_reference',
#  '_is_level_reference',
#  '_is_mixed_type',
#  '_is_view',
#  '_iset_item',
#  '_iter_column_arrays',
#  '_ix',
#  '_ixs',
#  '_join_compat',
#  '_maybe_cache_changed',
#  '_maybe_update_cacher',
#  '_metadata',
#  '_needs_reindex_multi',
#  '_obj_with_exclusions',
#  '_protect_consolidate',
#  '_reduce',
#  '_reindex_axes',
#  '_reindex_columns',
#  '_reindex_index',
#  '_reindex_multi',
#  '_reindex_with_indexers',
#  '_replace_columnwise',
#  '_repr_data_resource_',
#  '_repr_fits_horizontal_',
#  '_repr_fits_vertical_',
#  '_repr_html_',
#  '_repr_latex_',
#  '_reset_cache',
#  '_reset_cacher',
#  '_sanitize_column',
#  '_selected_obj',
#  '_selection',
#  '_selection_list',
#  '_selection_name',
#  '_series',
#  '_set_as_cached',
#  '_set_axis',
#  '_set_axis_name',
#  '_set_is_copy',
#  '_set_item',
#  '_set_value',
#  '_setitem_array',
#  '_setitem_frame',
#  '_setitem_slice',
#  '_slice',
#  '_stat_axis',
#  '_stat_axis_name',
#  '_stat_axis_number',
#  '_take_with_is_copy',
#  '_to_dict_of_blocks',
#  '_try_aggregate_string_function',
#  '_typ',
#  '_update_inplace',
#  '_validate_dtype',
#  '_values',
#  '_where',
#  'abs',
#  'add',
#  'add_prefix',
#  'add_suffix',
#  'agg',
#  'aggregate',
#  'align',
#  'all',
#  'any',
#  'append',
#  'apply',
#  'applymap',
#  'asfreq',
#  'asof',
#  'assign',
#  'astype',
#  'at',
#  'at_time',
#  'attrs',
#  'avg_score_15',
#  'avg_score_16',
#  'axes',
#  'backfill',
#  'between_time',
#  'bfill',
#  'bool',
#  'boxplot',
#  'clip',
#  'columns',
#  'combine',
#  'combine_first',
#  'compare',
#  'convert_dtypes',
#  'copy',
#  'corr',
#  'corrwith',
#  'count',
#  'cov',
#  'cummax',
#  'cummin',
#  'cumprod',
#  'cumsum',
#  'describe',
#  'diff',
#  'div',
#  'divide',
#  'dot',
#  'drop',
#  'drop_duplicates',
#  'droplevel',
#  'dropna',
#  'dtypes',
#  'duplicated',
#  'empty',
#  'eq',
#  'equals',
#  'eval',
#  'ewm',
#  'expanding',
#  'explode',
#  'ffill',
#  'fillna',
#  'filter',
#  'first',
#  'first_valid_index',
#  'floordiv',
#  'from_dict',
#  'from_records',
#  'full_time_teachers',
#  'ge',
#  'get',
#  'groupby',
#  'gt',
#  'head',
#  'hist',
#  'iat',
#  'idxmax',
#  'idxmin',
#  'iloc',
#  'index',
#  'infer_objects',
#  'info',
#  'insert',
#  'interpolate',
#  'isin',
#  'isna',
#  'isnull',
#  'items',
#  'iteritems',
#  'iterrows',
#  'itertuples',
#  'join',
#  'keys',
#  'kurt',
#  'kurtosis',
#  'last',
#  'last_valid_index',
#  'le',
#  'loc',
#  'lookup',
#  'lt',
#  'mad',
#  'mask',
#  'max',
#  'mean',
#  'median',
#  'melt',
#  'memory_usage',
#  'merge',
#  'min',
#  'mod',
#  'mode',
#  'mul',
#  'multiply',
#  'ndim',
#  'ne',
#  'nlargest',
#  'notna',
#  'notnull',
#  'nsmallest',
#  'nunique',
#  'pad',
#  'pct_change',
#  'percent_asian',
#  'percent_black',
#  'percent_hispanic',
#  'percent_white',
#  'pipe',
#  'pivot',
#  'pivot_table',
#  'plot',
#  'pop',
#  'pow',
#  'prod',
#  'product',
#  'quantile',
#  'query',
#  'radd',
#  'rank',
#  'rdiv',
#  'reduced_lunch',
#  'reindex',
#  'reindex_like',
#  'rename',
#  'rename_axis',
#  'reorder_levels',
#  'replace',
#  'resample',
#  'reset_index',
#  'rfloordiv',
#  'rmod',
#  'rmul',
#  'rolling',
#  'round',
#  'rpow',
#  'rsub',
#  'rtruediv',
#  'sample',
#  'school_rating',
#  'select_dtypes',
#  'sem',
#  'set_axis',
#  'set_index',
#  'shape',
#  'shift',
#  'size',
#  'skew',
#  'slice_shift',
#  'sort_index',
#  'sort_values',
#  'squeeze',
#  'stack',
#  'state_percentile_15',
#  'state_percentile_16',
#  'std',
#  'stu_teach_ratio',
#  'style',
#  'sub',
#  'subtract',
#  'sum',
#  'swapaxes',
#  'swaplevel',
#  'tail',
#  'take',
#  'to_clipboard',
#  'to_csv',
#  'to_dict',
#  'to_excel',
#  'to_feather',
#  'to_gbq',
#  'to_hdf',
#  'to_html',
#  'to_json',
#  'to_latex',
#  'to_markdown',
#  'to_numpy',
#  'to_parquet',
#  'to_period',
#  'to_pickle',
#  'to_records',
#  'to_sql',
#  'to_stata',
#  'to_string',
#  'to_timestamp',
#  'to_xarray',
#  'transform',
#  'transpose',
#  'truediv',
#  'truncate',
#  'tz_convert',
#  'tz_localize',
#  'unstack',
#  'update',
#  'value_counts',
#  'values',
#  'var',
#  'where',
#  'xs']

# %%
quant_df.mean()
# Out:
# school_rating            2.968300
# size                   699.472622
# reduced_lunch           50.279539
# state_percentile_16     58.801729
# state_percentile_15     58.249267
# stu_teach_ratio         15.461671
# avg_score_15            57.004692
# avg_score_16            57.049856
# full_time_teachers      44.939481
# percent_black           21.197983
# percent_white           61.673487
# percent_asian            2.642651
# percent_hispanic        11.164553
# dtype: float64

# %%
quant_df.mean(axis=1)
# Out:
# 0      107.069231
# 1       59.823077
# 2       75.646154
# 3       48.938462
# 4      114.484615
#           ...
# 342     82.000000
# 343     80.646154
# 344     71.638462
# 345    107.600000
# 346     84.761538
# Length: 347, dtype: float64

# %%
quant_df.var()
# Out:
# school_rating               2.857374
# size                   160479.267312
# reduced_lunch             649.242441
# state_percentile_16      1058.900228
# state_percentile_15      1069.461977
# stu_teach_ratio            32.777573
# avg_score_15              712.700449
# avg_score_16              782.263490
# full_time_teachers        486.351818
# percent_black             555.193204
# percent_white             743.917908
# percent_asian               9.669794
# percent_hispanic          144.735532
# dtype: float64

# %%
quant_df.sum()
# Out:
# school_rating            1030.0
# size                   242717.0
# reduced_lunch           17447.0
# state_percentile_16     20404.2
# state_percentile_15     19863.0
# stu_teach_ratio          5365.2
# avg_score_15            19438.6
# avg_score_16            19796.3
# full_time_teachers      15594.0
# percent_black            7355.7
# percent_white           21400.7
# percent_asian             917.0
# percent_hispanic         3874.1
# dtype: float64

# %%
quant_df.std()
# Out:
# school_rating            1.690377
# size                   400.598636
# reduced_lunch           25.480236
# state_percentile_16     32.540747
# state_percentile_15     32.702630
# stu_teach_ratio          5.725170
# avg_score_15            26.696450
# avg_score_16            27.968974
# full_time_teachers      22.053386
# percent_black           23.562538
# percent_white           27.274859
# percent_asian            3.109629
# percent_hispanic        12.030608
# dtype: float64

# %%
quant_df.count()
# Out:
# school_rating          347
# size                   347
# reduced_lunch          347
# state_percentile_16    347
# state_percentile_15    341
# stu_teach_ratio        347
# avg_score_15           341
# avg_score_16           347
# full_time_teachers     347
# percent_black          347
# percent_white          347
# percent_asian          347
# percent_hispanic       347
# dtype: int64

# %%
dir(quant_df)
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_NAMES',
#  '_AXIS_NUMBERS',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '_AXIS_TO_AXIS_NUMBER',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__nonzero__',
#  '__or__',
#  '__pos__',
#  '__pow__',
#  '__radd__',
#  '__rand__',
#  '__rdiv__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rfloordiv__',
#  '__rmatmul__',
#  '__rmod__',
#  '__rmul__',
#  '__ror__',
#  '__round__',
#  '__rpow__',
#  '__rsub__',
#  '__rtruediv__',
#  '__rxor__',
#  '__setattr__',
#  '__setitem__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
#  '__weakref__',
#  '__xor__',
#  '_accessors',
#  '_add_numeric_operations',
#  '_add_series_or_dataframe_operations',
#  '_agg_by_level',
#  '_agg_examples_doc',
#  '_agg_summary_and_see_also_doc',
#  '_aggregate',
#  '_aggregate_multiple_funcs',
#  '_align_frame',
#  '_align_series',
#  '_box_col_values',
#  '_builtin_table',
#  '_can_fast_transpose',
#  '_check_inplace_setting',
#  '_check_is_chained_assignment_possible',
#  '_check_label_or_level_ambiguity',
#  '_check_setitem_copy',
#  '_clear_item_cache',
#  '_clip_with_one_bound',
#  '_clip_with_scalar',
#  '_combine_frame',
#  '_consolidate',
#  '_consolidate_inplace',
#  '_construct_axes_dict',
#  '_construct_axes_from_arguments',
#  '_construct_result',
#  '_constructor',
#  '_constructor_expanddim',
#  '_constructor_sliced',
#  '_convert',
#  '_count_level',
#  '_cython_table',
#  '_data',
#  '_deprecations',
#  '_dir_additions',
#  '_dir_deletions',
#  '_drop_axis',
#  '_drop_labels_or_levels',
#  '_ensure_valid_index',
#  '_find_valid_index',
#  '_from_arrays',
#  '_get_agg_axis',
#  '_get_axis',
#  '_get_axis_name',
#  '_get_axis_number',
#  '_get_axis_resolvers',
#  '_get_block_manager_axis',
#  '_get_bool_data',
#  '_get_cacher',
#  '_get_cleaned_column_resolvers',
#  '_get_column_array',
#  '_get_cython_func',
#  '_get_index_resolvers',
#  '_get_item_cache',
#  '_get_label_or_level_values',
#  '_get_numeric_data',
#  '_get_value',
#  '_getitem_bool_array',
#  '_getitem_multilevel',
#  '_gotitem',
#  '_indexed_same',
#  '_info_axis',
#  '_info_axis_name',
#  '_info_axis_number',
#  '_info_repr',
#  '_init_mgr',
#  '_internal_names',
#  '_internal_names_set',
#  '_is_builtin_func',
#  '_is_cached',
#  '_is_copy',
#  '_is_homogeneous_type',
#  '_is_label_or_level_reference',
#  '_is_label_reference',
#  '_is_level_reference',
#  '_is_mixed_type',
#  '_is_view',
#  '_iset_item',
#  '_iter_column_arrays',
#  '_ix',
#  '_ixs',
#  '_join_compat',
#  '_maybe_cache_changed',
#  '_maybe_update_cacher',
#  '_metadata',
#  '_needs_reindex_multi',
#  '_obj_with_exclusions',
#  '_protect_consolidate',
#  '_reduce',
#  '_reindex_axes',
#  '_reindex_columns',
#  '_reindex_index',
#  '_reindex_multi',
#  '_reindex_with_indexers',
#  '_replace_columnwise',
#  '_repr_data_resource_',
#  '_repr_fits_horizontal_',
#  '_repr_fits_vertical_',
#  '_repr_html_',
#  '_repr_latex_',
#  '_reset_cache',
#  '_reset_cacher',
#  '_sanitize_column',
#  '_selected_obj',
#  '_selection',
#  '_selection_list',
#  '_selection_name',
#  '_series',
#  '_set_as_cached',
#  '_set_axis',
#  '_set_axis_name',
#  '_set_is_copy',
#  '_set_item',
#  '_set_value',
#  '_setitem_array',
#  '_setitem_frame',
#  '_setitem_slice',
#  '_slice',
#  '_stat_axis',
#  '_stat_axis_name',
#  '_stat_axis_number',
#  '_take_with_is_copy',
#  '_to_dict_of_blocks',
#  '_try_aggregate_string_function',
#  '_typ',
#  '_update_inplace',
#  '_validate_dtype',
#  '_values',
#  '_where',
#  'abs',
#  'add',
#  'add_prefix',
#  'add_suffix',
#  'agg',
#  'aggregate',
#  'align',
#  'all',
#  'any',
#  'append',
#  'apply',
#  'applymap',
#  'asfreq',
#  'asof',
#  'assign',
#  'astype',
#  'at',
#  'at_time',
#  'attrs',
#  'avg_score_15',
#  'avg_score_16',
#  'axes',
#  'backfill',
#  'between_time',
#  'bfill',
#  'bool',
#  'boxplot',
#  'clip',
#  'columns',
#  'combine',
#  'combine_first',
#  'compare',
#  'convert_dtypes',
#  'copy',
#  'corr',
#  'corrwith',
#  'count',
#  'cov',
#  'cummax',
#  'cummin',
#  'cumprod',
#  'cumsum',
#  'describe',
#  'diff',
#  'div',
#  'divide',
#  'dot',
#  'drop',
#  'drop_duplicates',
#  'droplevel',
#  'dropna',
#  'dtypes',
#  'duplicated',
#  'empty',
#  'eq',
#  'equals',
#  'eval',
#  'ewm',
#  'expanding',
#  'explode',
#  'ffill',
#  'fillna',
#  'filter',
#  'first',
#  'first_valid_index',
#  'floordiv',
#  'from_dict',
#  'from_records',
#  'full_time_teachers',
#  'ge',
#  'get',
#  'groupby',
#  'gt',
#  'head',
#  'hist',
#  'iat',
#  'idxmax',
#  'idxmin',
#  'iloc',
#  'index',
#  'infer_objects',
#  'info',
#  'insert',
#  'interpolate',
#  'isin',
#  'isna',
#  'isnull',
#  'items',
#  'iteritems',
#  'iterrows',
#  'itertuples',
#  'join',
#  'keys',
#  'kurt',
#  'kurtosis',
#  'last',
#  'last_valid_index',
#  'le',
#  'loc',
#  'lookup',
#  'lt',
#  'mad',
#  'mask',
#  'max',
#  'mean',
#  'median',
#  'melt',
#  'memory_usage',
#  'merge',
#  'min',
#  'mod',
#  'mode',
#  'mul',
#  'multiply',
#  'ndim',
#  'ne',
#  'nlargest',
#  'notna',
#  'notnull',
#  'nsmallest',
#  'nunique',
#  'pad',
#  'pct_change',
#  'percent_asian',
#  'percent_black',
#  'percent_hispanic',
#  'percent_white',
#  'pipe',
#  'pivot',
#  'pivot_table',
#  'plot',
#  'pop',
#  'pow',
#  'prod',
#  'product',
#  'quantile',
#  'query',
#  'radd',
#  'rank',
#  'rdiv',
#  'reduced_lunch',
#  'reindex',
#  'reindex_like',
#  'rename',
#  'rename_axis',
#  'reorder_levels',
#  'replace',
#  'resample',
#  'reset_index',
#  'rfloordiv',
#  'rmod',
#  'rmul',
#  'rolling',
#  'round',
#  'rpow',
#  'rsub',
#  'rtruediv',
#  'sample',
#  'school_rating',
#  'select_dtypes',
#  'sem',
#  'set_axis',
#  'set_index',
#  'shape',
#  'shift',
#  'size',
#  'skew',
#  'slice_shift',
#  'sort_index',
#  'sort_values',
#  'squeeze',
#  'stack',
#  'state_percentile_15',
#  'state_percentile_16',
#  'std',
#  'stu_teach_ratio',
#  'style',
#  'sub',
#  'subtract',
#  'sum',
#  'swapaxes',
#  'swaplevel',
#  'tail',
#  'take',
#  'to_clipboard',
#  'to_csv',
#  'to_dict',
#  'to_excel',
#  'to_feather',
#  'to_gbq',
#  'to_hdf',
#  'to_html',
#  'to_json',
#  'to_latex',
#  'to_markdown',
#  'to_numpy',
#  'to_parquet',
#  'to_period',
#  'to_pickle',
#  'to_records',
#  'to_sql',
#  'to_stata',
#  'to_string',
#  'to_timestamp',
#  'to_xarray',
#  'transform',
#  'transpose',
#  'truediv',
#  'truncate',
#  'tz_convert',
#  'tz_localize',
#  'unstack',
#  'update',
#  'value_counts',
#  'values',
#  'var',
#  'where',
#  'xs']

# %%
quant_df.aggregate(['sum', 'mean'])
# Out:
#       school_rating           size  reduced_lunch  state_percentile_16  \
# sum       1030.0000  242717.000000   17447.000000         20404.200000
# mean         2.9683     699.472622      50.279539            58.801729
#
#       state_percentile_15  stu_teach_ratio  avg_score_15  avg_score_16  \
# sum          19863.000000      5365.200000  19438.600000  19796.300000
# mean            58.249267        15.461671     57.004692     57.049856
#
#       full_time_teachers  percent_black  percent_white  percent_asian  \
# sum         15594.000000    7355.700000   21400.700000     917.000000
# mean           44.939481      21.197983      61.673487       2.642651
#
#       percent_hispanic
# sum        3874.100000
# mean         11.164553

# %%
def square(x):
    return x**2

# %%
square(55)
# Out:
# 3025

# %%
(lambda x: x**2)(55)
# Out:
# 3025

# %%
quant_df.aggregate(['min', 'max']).unstack()
# Out:
# school_rating        min       0.0
#                      max       5.0
# size                 min      53.0
#                      max    2314.0
# reduced_lunch        min       2.0
#                      max      98.0
# state_percentile_16  min       0.2
#                      max      99.8
# state_percentile_15  min       0.6
#                      max      99.8
# stu_teach_ratio      min       4.7
#                      max     111.0
# avg_score_15         min       1.5
#                      max      99.0
# avg_score_16         min       0.1
#                      max      98.9
# full_time_teachers   min       2.0
#                      max     140.0
# percent_black        min       0.0
#                      max      97.4
# percent_white        min       1.1
#                      max      99.7
# percent_asian        min       0.0
#                      max      21.1
# percent_hispanic     min       0.0
#                      max      65.2
# dtype: float64

# %%
quant_df.aggregate(lambda x: np.sin(x))
# Out:
#      school_rating      size  reduced_lunch  state_percentile_16  \
# 0        -0.958924  0.363115      -0.544021             0.787158
# 1         0.909297 -0.436192       0.951055             0.982618
# 2        -0.756802 -0.972637      -0.831775             0.139361
# 3         0.000000 -0.963803       0.105988             0.999574
# 4        -0.756802 -0.689632       0.762558            -0.459115
# ..             ...       ...            ...                  ...
# 342       0.141120  0.999209       0.436165             0.556577
# 343      -0.958924 -0.219396       0.989358            -0.340811
# 344      -0.756802  0.114755      -0.999755             0.023000
# 345      -0.958924 -0.881756       0.909297            -0.812122
# 346       0.000000 -0.371348       0.860069            -0.977530
#
#      state_percentile_15  stu_teach_ratio  avg_score_15  avg_score_16  \
# 0               0.999827         0.007963      0.990849     -0.368131
# 1              -0.388600         0.231510     -0.831775      0.565375
# 2               0.940127        -0.778352      0.297217     -0.676772
# 3               0.841471         0.508661      0.863209     -0.951602
# 4               0.944282         0.788252     -0.372229     -0.872445
# ..                   ...              ...           ...           ...
# 342             0.698605        -0.929124     -0.990363      0.913307
# 343             0.379608         0.986772     -0.779466      0.972423
# 344             0.964032         0.999309      0.281121     -0.757962
# 345             0.285351         0.343315      0.965195     -0.076922
# 346             0.932039        -0.711785      0.427380     -0.174327
#
#      full_time_teachers  percent_black  percent_white  percent_asian  \
# 0             -0.558789       0.239249      -0.626456       0.999574
# 1              0.551427      -0.687766      -0.953485       0.841471
# 2             -0.663634       0.841471      -0.383712       0.932039
# 3             -0.988032      -0.831281      -0.761984       0.745705
# 4              0.920026      -0.693525       0.870704       0.728969
# ..                  ...            ...            ...            ...
# 342           -0.991779       0.486399      -0.320781       0.997495
# 343           -0.991779      -0.157746      -0.535073       0.041581
# 344           -0.988032      -0.822829       0.982782       0.863209
# 345            0.850904      -0.977530       0.807450      -0.544021
# 346           -0.262375      -0.303965       0.836656       0.311541
#
#      percent_hispanic
# 0           -0.631267
# 1           -0.982453
# 2           -0.951602
# 3           -0.916166
# 4           -0.279415
# ..                ...
# 342          0.007963
# 343         -0.818277
# 344         -0.271761
# 345         -0.951602
# 346         -0.692885
#
# [347 rows x 13 columns]

# %%
import pandas as pd
world_cup={'Team':['West Indies','West indies','India','Australia','Pakistan','Sri 	Lanka','Australia','Australia','Australia','Insia','Australia'],
           'Rank':[7,7,2,1,6,4,1,1,1,2,1],  
           'Year':[1975,1979,1983,1987,1992,1996,1999,2003,2007,2011,2015]}

# %%
df=pd.DataFrame(world_cup)

# %%
df
# Out:
#            Team  Rank  Year
# 0   West Indies     7  1975
# 1   West indies     7  1979
# 2         India     2  1983
# 3     Australia     1  1987
# 4      Pakistan     6  1992
# 5   Sri \tLanka     4  1996
# 6     Australia     1  1999
# 7     Australia     1  2003
# 8     Australia     1  2007
# 9         Insia     2  2011
# 10    Australia     1  2015

# %%
df.groupby(['Team','Rank']).groups
# Out:
# {('Australia', 1): [3, 6, 7, 8, 10], ('India', 2): [2], ('Insia', 2): [9], ('Pakistan', 6): [4], ('Sri 	Lanka', 4): [5], ('West Indies', 7): [0], ('West indies', 7): [1]}

# %%
df = pd.read_csv('Demo Datasets/Lesson 3/middle_tn_schools.csv')

# %%
grouped_mean = df.groupby('school_type').mean()

# %%
grouped_mean
# Out:
#                 school_rating        size  reduced_lunch  state_percentile_16  \
# school_type
# Public               3.092466  717.027397      48.352740            60.970548
# Public Charter       3.375000  368.875000      76.625000            69.925000
# Public Magnet        2.065217  655.913043      58.434783            42.404348
# Public Virtual       5.000000  222.000000      27.000000            90.800000
#
#                 state_percentile_15  stu_teach_ratio  avg_score_15  \
# school_type
# Public                    60.391667        15.190753     58.917014
# Public Charter            72.850000        15.312500     67.966667
# Public Magnet             42.839130        15.130435     43.519565
# Public Virtual            62.500000       111.000000     60.800000
#
#                 avg_score_16  full_time_teachers  percent_black  \
# school_type
# Public             58.939041           46.126712      15.480479
# Public Charter     65.087500           24.500000      50.312500
# Public Magnet      43.208696           41.891304      52.713043
# Public Virtual     77.800000            2.000000       8.100000
#
#                 percent_white  percent_asian  percent_hispanic
# school_type
# Public              66.990411       2.672945         11.234589
# Public Charter      14.450000       1.262500         33.362500
# Public Magnet       35.615217       2.717391          7.071739
# Public Virtual      85.600000       1.400000          1.400000

# %%
import pandas as pd

one = pd.DataFrame({
   'Name': ['Alex', 'Amy', 'Allen', 'Alice', 'Ayoung'],
   'subject_id':['sub1','sub2','sub4','sub6','sub5'],
   'Marks_scored':[98,90,87,69,78]},
   index=[1,2,3,4,6])

two = pd.DataFrame({
   'Name': ['Billy', 'Brian', 'Bran', 'Bryce', 'Betty'],
   'subject_id':['sub2','sub4','sub3','sub6','sub5'],
   'Marks_scored':[89,80,79,97,88]},
   index=[1,2,3,4,5])

# %%
one
# Out:
#      Name subject_id  Marks_scored
# 1    Alex       sub1            98
# 2     Amy       sub2            90
# 3   Allen       sub4            87
# 4   Alice       sub6            69
# 6  Ayoung       sub5            78

# %%
two
# Out:
#     Name subject_id  Marks_scored
# 1  Billy       sub2            89
# 2  Brian       sub4            80
# 3   Bran       sub3            79
# 4  Bryce       sub6            97
# 5  Betty       sub5            88

# %%
data = pd.concat([one,two],axis=0)

# %%
data
# Out:
#      Name subject_id  Marks_scored
# 1    Alex       sub1            98
# 2     Amy       sub2            90
# 3   Allen       sub4            87
# 4   Alice       sub6            69
# 6  Ayoung       sub5            78
# 1   Billy       sub2            89
# 2   Brian       sub4            80
# 3    Bran       sub3            79
# 4   Bryce       sub6            97
# 5   Betty       sub5            88

# %%
import pandas as pd

one = pd.DataFrame({
   'Name': ['Alex', 'Amy', 'Allen', 'Alice', 'Ayoung'],
   'subject_id':['sub1','sub2','sub4','sub6','sub5'],
   'Marks_scored':[98,90,87,69,78]},
   index=[1,2,3,4,6])

two = pd.DataFrame({
   'Name_1': ['Billy', 'Brian', 'Bran', 'Bryce', 'Betty'],
   'subject_id':['sub2','sub4','sub3','sub6','sub5'],
   'Marks_scored_1':[89,80,79,97,88]},
   index=[1,2,3,4,5])

# %%
one
# Out:
#      Name subject_id  Marks_scored
# 1    Alex       sub1            98
# 2     Amy       sub2            90
# 3   Allen       sub4            87
# 4   Alice       sub6            69
# 6  Ayoung       sub5            78

# %%
two
# Out:
#   Name_1 subject_id  Marks_scored_1
# 1  Billy       sub2              89
# 2  Brian       sub4              80
# 3   Bran       sub3              79
# 4  Bryce       sub6              97
# 5  Betty       sub5              88

# %%
data = pd.concat([one,two],axis=0)

# %%
data
# Out:
#      Name subject_id  Marks_scored Name_1  Marks_scored_1
# 1    Alex       sub1          98.0    NaN             NaN
# 2     Amy       sub2          90.0    NaN             NaN
# 3   Allen       sub4          87.0    NaN             NaN
# 4   Alice       sub6          69.0    NaN             NaN
# 6  Ayoung       sub5          78.0    NaN             NaN
# 1     NaN       sub2           NaN  Billy            89.0
# 2     NaN       sub4           NaN  Brian            80.0
# 3     NaN       sub3           NaN   Bran            79.0
# 4     NaN       sub6           NaN  Bryce            97.0
# 5     NaN       sub5           NaN  Betty            88.0

# %%
import pandas as pd

one = pd.DataFrame({
   'Name': ['Alex', 'Amy', 'Allen', 'Alice', 'Ayoung'],
   'subject_id':['sub1','sub2','sub4','sub6','sub5'],
   'Marks_scored':[98,90,87,69,78]},
   index=[1,2,3,4,6])

two = pd.DataFrame({
   'Name': ['Billy', 'Brian', 'Bran', 'Bryce', 'Betty'],
   'subject_id':['sub2','sub4','sub3','sub6','sub5'],
   'Marks_scored':[89,80,79,97,88]},
   index=[1,2,3,4,5])

# %%
one
# Out:
#      Name subject_id  Marks_scored
# 1    Alex       sub1            98
# 2     Amy       sub2            90
# 3   Allen       sub4            87
# 4   Alice       sub6            69
# 6  Ayoung       sub5            78

# %%
two
# Out:
#     Name subject_id  Marks_scored
# 1  Billy       sub2            89
# 2  Brian       sub4            80
# 3   Bran       sub3            79
# 4  Bryce       sub6            97
# 5  Betty       sub5            88

# %%
data = pd.concat([one,two],axis=1)

# %%
data
# Out:
#      Name subject_id  Marks_scored   Name subject_id  Marks_scored
# 1    Alex       sub1          98.0  Billy       sub2          89.0
# 2     Amy       sub2          90.0  Brian       sub4          80.0
# 3   Allen       sub4          87.0   Bran       sub3          79.0
# 4   Alice       sub6          69.0  Bryce       sub6          97.0
# 5     NaN        NaN           NaN  Betty       sub5          88.0
# 6  Ayoung       sub5          78.0    NaN        NaN           NaN

# %%
one
# Out:
#      Name subject_id  Marks_scored
# 1    Alex       sub1            98
# 2     Amy       sub2            90
# 3   Allen       sub4            87
# 4   Alice       sub6            69
# 6  Ayoung       sub5            78

# %%
two
# Out:
#     Name subject_id  Marks_scored
# 1  Billy       sub2            89
# 2  Brian       sub4            80
# 3   Bran       sub3            79
# 4  Bryce       sub6            97
# 5  Betty       sub5            88

# %%
pd.concat([two,one],axis=1)
# Out:
#     Name subject_id  Marks_scored    Name subject_id  Marks_scored
# 1  Billy       sub2          89.0    Alex       sub1          98.0
# 2  Brian       sub4          80.0     Amy       sub2          90.0
# 3   Bran       sub3          79.0   Allen       sub4          87.0
# 4  Bryce       sub6          97.0   Alice       sub6          69.0
# 5  Betty       sub5          88.0     NaN        NaN           NaN
# 6    NaN        NaN           NaN  Ayoung       sub5          78.0

# %%
pd.concat([one,two],axis=1,join='inner')
# Out:
#     Name subject_id  Marks_scored   Name subject_id  Marks_scored
# 1   Alex       sub1            98  Billy       sub2            89
# 2    Amy       sub2            90  Brian       sub4            80
# 3  Allen       sub4            87   Bran       sub3            79
# 4  Alice       sub6            69  Bryce       sub6            97

# %%
one
# Out:
#      Name subject_id  Marks_scored
# 1    Alex       sub1            98
# 2     Amy       sub2            90
# 3   Allen       sub4            87
# 4   Alice       sub6            69
# 6  Ayoung       sub5            78

# %%
two
# Out:
#     Name subject_id  Marks_scored
# 1  Billy       sub2            89
# 2  Brian       sub4            80
# 3   Bran       sub3            79
# 4  Bryce       sub6            97
# 5  Betty       sub5            88

# %% [markdown]
# * left   : LEFT OUTER JOIN    : Use keys from left frame only
# * right  : RIGHT OUTER JOIN   : Use keys from right frame only
# * outer  : FULL OUTER JOIN    : Use union of keys from both frames
# * inner  : INNER JOIN         : Use intersection of keys from both frames : default

# %%
data = pd.merge(one,two,how='inner',on='subject_id',suffixes=('_one','_two'))
data
# Out:
#   Name_one subject_id  Marks_scored_one Name_two  Marks_scored_two
# 0      Amy       sub2                90    Billy                89
# 1    Allen       sub4                87    Brian                80
# 2    Alice       sub6                69    Bryce                97
# 3   Ayoung       sub5                78    Betty                88

# %%
pd.merge(two,one,how='outer',on='subject_id')
# Out:
#   Name_x subject_id  Marks_scored_x  Name_y  Marks_scored_y
# 0  Billy       sub2            89.0     Amy            90.0
# 1  Brian       sub4            80.0   Allen            87.0
# 2   Bran       sub3            79.0     NaN             NaN
# 3  Bryce       sub6            97.0   Alice            69.0
# 4  Betty       sub5            88.0  Ayoung            78.0
# 5    NaN       sub1             NaN    Alex            98.0

# %%
one
# Out:
#      Name subject_id  Marks_scored
# 1    Alex       sub1            98
# 2     Amy       sub2            90
# 3   Allen       sub4            87
# 4   Alice       sub6            69
# 6  Ayoung       sub5            78

# %%
two
# Out:
#     Name subject_id  Marks_scored
# 1  Billy       sub2            89
# 2  Brian       sub4            80
# 3   Bran       sub3            79
# 4  Bryce       sub6            97
# 5  Betty       sub5            88

# %%
pd.merge(one,two,how='right',on='subject_id')
# Out:
#    Name_x subject_id  Marks_scored_x Name_y  Marks_scored_y
# 0     Amy       sub2            90.0  Billy              89
# 1   Allen       sub4            87.0  Brian              80
# 2     NaN       sub3             NaN   Bran              79
# 3   Alice       sub6            69.0  Bryce              97
# 4  Ayoung       sub5            78.0  Betty              88

# %%
pd.merge(one,two,how='left',on='subject_id')
# Out:
#    Name_x subject_id  Marks_scored_x Name_y  Marks_scored_y
# 0    Alex       sub1              98    NaN             NaN
# 1     Amy       sub2              90  Billy            89.0
# 2   Allen       sub4              87  Brian            80.0
# 3   Alice       sub6              69  Bryce            97.0
# 4  Ayoung       sub5              78  Betty            88.0
